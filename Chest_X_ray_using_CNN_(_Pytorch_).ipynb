# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshukhanduri20/Chest-X-ray-analyse-ANN-CNN-/blob/main/Chest_X_ray_using_CNN_(_Pytorch_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00025583_005.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1513_virus_2632.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person124_virus_238.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person466_virus_960.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person59_bacteria_279.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person600_bacteria_2456.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person622_bacteria_2494.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1689_bacteria_4472.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person437_bacteria_1884.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1338_bacteria_3397.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person114_virus_217.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1585_bacteria_4151.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person412_bacteria_1827.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person318_bacteria_1474.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person579_bacteria_2381.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1906_bacteria_4803.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person266_bacteria_1245.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1490_virus_2596.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1010_bacteria_2941.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person535_bacteria_2255.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person321_bacteria_1487.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person775_virus_1404.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1585_bacteria_4155.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person300_bacteria_1422.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1409_virus_2413.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00015826_036.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1346_bacteria_3430.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person66_bacteria_325.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person590_virus_1138.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person53_bacteria_253.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person961_bacteria_2886.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person343_bacteria_1584.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1099_virus_1819.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person935_virus_1597.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1411_bacteria_3610.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person536_virus_1064.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1507_bacteria_3944.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1123_virus_1848.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1177_virus_2000.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person959_bacteria_2884.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1343_bacteria_3419.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1489_virus_2594.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person41_bacteria_209.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person909_virus_1565.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00027648_005.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person160_virus_316.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1265_virus_2156.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person360_bacteria_1647.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person337_bacteria_1557.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1663_bacteria_4412.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person419_virus_859.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1065_bacteria_2999.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person389_bacteria_1780.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person62_bacteria_301.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person629_bacteria_2506.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person431_bacteria_1872.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1494_virus_2601.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person312_virus_635.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00017659_000.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1016_virus_1704.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1701_bacteria_4504.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1368_virus_2354.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00007444_003.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1490_bacteria_3891.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00008727_009.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1059_bacteria_2993.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1491_virus_2597.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person531_bacteria_2241.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00020845_002.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1315_bacteria_3322.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1907_bacteria_4806.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person135_virus_270.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person156_virus_308.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1460_bacteria_3801.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person326_bacteria_1503.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1372_bacteria_3503.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00003950_002.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person369_bacteria_1680.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00021584_001.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person420_bacteria_1847.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00021706_004.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1155_virus_1934.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person441_bacteria_1904.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person925_bacteria_2850.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1158_virus_1940.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person476_bacteria_2026.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person449_bacteria_1940.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person259_bacteria_1217.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person393_virus_784.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person963_virus_1636.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person937_virus_1599.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00012297_004.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person7_bacteria_29.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person477_bacteria_2030.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person74_bacteria_362.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person277_bacteria_1306.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person61_bacteria_292.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person426_bacteria_1861.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person24_bacteria_110.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person581_virus_1125.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1715_bacteria_4532.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1366_bacteria_3490.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person22_bacteria_74.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person744_virus_1367.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person359_virus_738.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1449_bacteria_3743.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person41_bacteria_206.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1344_virus_2320.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person739_bacteria_2642.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person94_virus_176.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person108_virus_199.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person585_bacteria_2412.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person698_virus_1294.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person989_virus_1667.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person875_bacteria_2798.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person351_bacteria_1619.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person596_virus_1149.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person895_bacteria_2820.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1122_virus_1847.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1003_virus_1685.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person629_bacteria_2509.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person952_bacteria_2877.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1315_virus_2270.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1392_bacteria_3538.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person475_bacteria_2025.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person755_bacteria_2659.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person655_bacteria_2547.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person364_virus_743.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00011472_001.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person898_bacteria_2823.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1145_virus_1906.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person775_bacteria_2679.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person550_bacteria_2309.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person381_bacteria_1731.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1593_virus_2767.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1927_bacteria_4837.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person73_bacteria_359.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person41_bacteria_210.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person663_bacteria_2555.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1770_bacteria_4614.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person257_bacteria_1195.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person555_bacteria_2325.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00026629_006.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person356_virus_733.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person493_bacteria_2086.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person337_bacteria_1563.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person434_virus_884.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person565_bacteria_2348.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person985_bacteria_2912.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person477_bacteria_2028.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person593_bacteria_2435.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00028301_000.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1041_bacteria_2975.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person612_bacteria_2477.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person563_bacteria_2337.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person508_bacteria_2144.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person853_bacteria_2774.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00012158_025.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1298_bacteria_3261.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person332_bacteria_1534.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person962_virus_1635.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1241_virus_2106.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1639_bacteria_4344.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00011386_000.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person537_virus_1067.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1548_virus_2689.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person30_bacteria_149.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1015_virus_1702.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1062_bacteria_2996.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person351_bacteria_1622.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1348_virus_2326.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person24_bacteria_111.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person737_bacteria_2640.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1445_bacteria_3734.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person341_virus_699.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person336_bacteria_1553.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person37_bacteria_189.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1097_virus_1817.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person3_bacteria_11.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1056_virus_1755.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1599_bacteria_4201.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1652_bacteria_4383.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person383_bacteria_1748.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1453_bacteria_3771.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person802_bacteria_2708.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person100_virus_184.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1320_bacteria_3346.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00017005_000.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person370_bacteria_1691.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1883_bacteria_4769.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person971_bacteria_2896.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1680_bacteria_4455.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person435_bacteria_1879.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person380_virus_763.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person840_bacteria_2758.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person62_bacteria_298.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person145_virus_294.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1390_bacteria_3535.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person280_virus_577.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person43_bacteria_216.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person385_virus_770.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person67_bacteria_328.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person139_virus_283.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1008_bacteria_2939.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1216_virus_2062.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1168_virus_1966.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1868_bacteria_4743.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00001749_002.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person71_bacteria_347.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1368_virus_2353.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1333_bacteria_3384.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person516_bacteria_2192.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00016011_011.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person552_virus_1092.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person624_bacteria_2497.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1248_bacteria_3204.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person267_virus_552.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person366_bacteria_1664.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person319_bacteria_1479.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person835_virus_1472.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1332_virus_2300.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person70_bacteria_345.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person993_virus_1671.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person325_bacteria_1498.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person503_bacteria_2126.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person582_bacteria_2404.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1271_virus_2164.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person61_bacteria_294.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1411_bacteria_3602.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person27_bacteria_138.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1936_bacteria_4852.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person498_bacteria_2100.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person838_virus_1476.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1406_bacteria_3574.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1724_bacteria_4549.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1597_bacteria_4188.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person470_bacteria_1998.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person881_virus_1531.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person40_bacteria_203.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1452_virus_2484.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1270_virus_2163.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1167_bacteria_3113.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1721_bacteria_4546.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person939_bacteria_2864.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person604_bacteria_2462.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00026085_000.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person469_bacteria_1994.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person301_bacteria_1429.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person677_virus_1268.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person759_virus_1387.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1571_bacteria_4108.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1176_bacteria_3123.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person383_bacteria_1751.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person608_bacteria_2473.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1720_bacteria_4545.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person490_bacteria_2069.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person372_bacteria_1706.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1932_bacteria_4843.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1670_bacteria_4431.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person292_bacteria_1378.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person30_bacteria_156.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1269_bacteria_3229.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person73_bacteria_356.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person621_virus_1194.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person537_bacteria_2262.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1255_virus_2132.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person486_bacteria_2053.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1328_virus_2293.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person934_virus_1595.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1313_bacteria_3320.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00010375_001.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person712_bacteria_2613.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person968_virus_1642.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1275_bacteria_3237.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person606_bacteria_2469.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person507_bacteria_2139.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person699_bacteria_2598.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1145_bacteria_3090.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1597_bacteria_4189.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1471_bacteria_3831.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person844_virus_1487.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person586_bacteria_2418.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person637_bacteria_2529.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person942_virus_1611.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1409_bacteria_3583.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person346_virus_708.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1502_bacteria_3925.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person489_bacteria_2065.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person891_virus_1541.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person522_bacteria_2210.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person413_bacteria_1833.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00016825_000.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person804_bacteria_2711.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00014294_011.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person481_bacteria_2042.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1024_virus_1716.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1044_virus_1740.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person445_bacteria_1929.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person913_virus_1570.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1508_bacteria_3949.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person39_bacteria_200.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person348_virus_711.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1086_virus_1798.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1220_bacteria_3173.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person264_virus_547.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00000499_008.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person132_virus_266.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person620_virus_1192.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person427_bacteria_1865.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person688_virus_1281.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00014201_008.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1597_bacteria_4191.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1141_virus_1886.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person441_bacteria_1911.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1561_bacteria_4077.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00019962_002.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1180_virus_2013.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person82_virus_155.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person448_virus_922.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1170_virus_1969.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1472_bacteria_3834.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person61_bacteria_290.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person761_virus_1389.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1363_bacteria_3484.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person630_bacteria_2514.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1466_virus_2543.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person760_bacteria_2664.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person147_virus_297.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person769_bacteria_2673.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person539_bacteria_2270.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1411_bacteria_3601.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person30_bacteria_153.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person300_bacteria_1423.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1486_virus_2580.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person25_bacteria_119.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person59_bacteria_282.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person313_bacteria_1457.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1164_virus_1958.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1423_bacteria_3650.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1644_bacteria_4358.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person402_bacteria_1813.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person860_virus_1505.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1545_bacteria_4042.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person98_virus_182.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1312_virus_2261.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person500_bacteria_2107.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person354_bacteria_1633.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1440_bacteria_3723.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1471_virus_2549.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person448_bacteria_1933.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person572_bacteria_2368.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1535_bacteria_4016.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person367_bacteria_1665.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person563_bacteria_2333.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person51_bacteria_242.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1019_virus_1708.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1941_bacteria_4863.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person51_bacteria_246.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person338_bacteria_1568.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1667_bacteria_4418.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person517_virus_1034.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00025624_000.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person794_bacteria_2700.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person957_virus_1629.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1735_bacteria_4570.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person973_virus_1647.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00022965_004.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1619_bacteria_4271.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person551_bacteria_2310.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person632_bacteria_2521.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person620_virus_1191.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person23_bacteria_85.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1425_virus_2438.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1535_bacteria_4017.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person673_virus_1263.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person371_bacteria_1700.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1760_bacteria_4602.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1180_virus_2009.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person277_bacteria_1301.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person289_virus_593.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person596_bacteria_2447.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person288_virus_587.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person940_virus_1607.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1713_bacteria_4530.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1269_virus_2162.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person472_bacteria_2015.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1648_bacteria_4373.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1598_bacteria_4197.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1405_virus_2408.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1084_virus_1796.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person70_bacteria_342.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person442_virus_906.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1486_bacteria_3885.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1431_bacteria_3698.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person585_bacteria_2415.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person262_virus_544.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person997_virus_1678.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00003092_000.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person433_bacteria_1876.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person501_bacteria_2113.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person75_bacteria_367.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person337_bacteria_1561.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1458_virus_2503.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person73_bacteria_355.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person533_virus_1055.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person576_virus_1120.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person413_virus_844.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person258_bacteria_1216.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person465_bacteria_1976.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1875_bacteria_4756.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1594_virus_2768.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person280_bacteria_1321.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1482_virus_2571.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00018237_028.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person743_virus_1366.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person447_bacteria_1932.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1634_bacteria_4334.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person9_bacteria_41.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00026389_002.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00006717_007.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person51_bacteria_248.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person736_virus_1358.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person38_bacteria_195.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1263_bacteria_3221.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1020_bacteria_2951.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person557_bacteria_2327.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1626_bacteria_4291.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person498_bacteria_2102.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00025383_002.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person496_bacteria_2095.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person760_virus_1388.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00015442_000.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person113_virus_216.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1346_virus_2322.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1378_bacteria_3513.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person520_bacteria_2205.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1096_virus_1816.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person47_bacteria_229.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person299_bacteria_1418.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person58_bacteria_274.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00013272_005.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person104_virus_191.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person614_bacteria_2480.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1375_virus_2366.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1663_bacteria_4411.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person505_bacteria_2135.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person334_bacteria_1544.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person618_bacteria_2489.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person459_bacteria_1956.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1411_bacteria_3591.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1333_virus_2301.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person294_bacteria_1386.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person563_bacteria_2340.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person26_bacteria_130.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person23_bacteria_86.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1414_virus_2424.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person396_bacteria_1796.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person371_bacteria_1701.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person520_virus_1039.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00005639_003.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person44_bacteria_218.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person371_bacteria_1696.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person32_bacteria_165.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1149_bacteria_3094.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person292_virus_602.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00012733_000.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person491_bacteria_2082.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person321_bacteria_1489.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1730_bacteria_4558.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person500_bacteria_2109.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person348_bacteria_1601.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person776_bacteria_2680.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person263_virus_546.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1376_bacteria_3511.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person25_bacteria_116.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1576_virus_2734.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1488_bacteria_3887.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1944_bacteria_4869.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/00016991_002.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person371_bacteria_1695.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1087_bacteria_3027.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person347_bacteria_1599.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person499_virus_1008.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person332_bacteria_1535.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person374_bacteria_1710.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person767_bacteria_2671.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person1081_virus_1793.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/pneumonia/person517_bacteria_2196.jpeg
# ...
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (276).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(128).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (80).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/043.JPG
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (245).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(442).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/320.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(554).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/168.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/535.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/266.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(331).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/254.jfif
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (840).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (322).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (714).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(254).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(361).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (811).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/7C69C012-7479-493F-8722-ABC29C60A2DD-1068x1063.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(515).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/557.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/335.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (211).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(99).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(464).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/232.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/613.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/008.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/600.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (598).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/381.PNG
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (781).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (220).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/f6575117.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/485-.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(269).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (852).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/F051E018-DAD1-4506-AD43-BE4CA29E960B-1068x1142.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(507).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(407).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(479).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(322).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (338).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (577).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (748).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(292).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(24).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(88).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(360).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (828).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/694.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/679.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (324).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/714.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(144).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/505.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/566.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (97).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/090.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (444).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (101).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (183).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/248.jfif
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (235).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/01E392EE-69F9-4E33-BFCE-E5C968654078-768x572.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/83.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/a361d7b7.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (491).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/112.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (343).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (96).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (247).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(425).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(317).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/558.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(470).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(210).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/611.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(394).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/298.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (377).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (105).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(130).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/48c4542c.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(150).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/306.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (653).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/699.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (440).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/750.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(230).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (601).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (110).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (806).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/607-.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (143).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (538).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/693.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(467).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/423.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(132).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(52).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/165.jfif
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/560.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (171).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (658).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(352).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/544.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/307.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (661).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/735.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(326).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(402).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/422.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (687).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/568.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/133.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (216).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/388.PNG
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/508.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/304.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(376).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/633.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/075.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (418).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (622).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (285).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (104).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(87).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/315.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(284).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (680).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (869).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(495).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (312).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (542).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(82).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(118).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/218.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (423).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (636).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(416).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(140).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(364).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (590).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (2).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/213.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(386).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(408).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (30).jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(358).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (698).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (509).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(184).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (387).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(203).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (825).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/518.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (789).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/044.JPG
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(73).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (341).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/372.jfif
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(451).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(32).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (389).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (241).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(340).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(235).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (616).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(83).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (568).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(418).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (524).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (339).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/f8335316.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (20).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (671).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/085.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/753.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (17).jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/659.png
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(535).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(131).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (10).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (841).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/7AF6C1AF-D249-4BD2-8C26-449304105D03-1068x881.jpeg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (75).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID19(384).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (715).jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/728.jpg
# /kaggle/input/covid19-pneumonia-normal-chest-xray-pa-dataset/covid/COVID-19 (405).jpg

# %%
BASE_PATH = '../input/covid19-pneumonia-normal-chest-xray-pa-dataset/'

# %%
image=[]
labels=[]
for file in os.listdir(BASE_PATH):
    if file=='covid':
        for c in os.listdir(os.path.join(BASE_PATH, file)):
            image.append(c)
            labels.append('covid')
    if file=='normal':
        for c in os.listdir(os.path.join(BASE_PATH, file)):
            image.append(c)
            labels.append('normal')
    if file=='pneumonia':
        for c in os.listdir(os.path.join(BASE_PATH, file)):
            image.append(c)
            labels.append('pneumonia')
data = {'Images':image, 'labels':labels} 
data = pd.DataFrame(data) 
data.head()
# Out:
#                        Images     labels
# 0            00025583_005.png  pneumonia
# 1  person1513_virus_2632.jpeg  pneumonia
# 2    person124_virus_238.jpeg  pneumonia
# 3    person466_virus_960.jpeg  pneumonia
# 4  person59_bacteria_279.jpeg  pneumonia

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
data['encoded_labels'] = lb.fit_transform(data['labels'])
data.head()
# Out:
#                        Images     labels  encoded_labels
# 0            00025583_005.png  pneumonia               2
# 1  person1513_virus_2632.jpeg  pneumonia               2
# 2    person124_virus_238.jpeg  pneumonia               2
# 3    person466_virus_960.jpeg  pneumonia               2
# 4  person59_bacteria_279.jpeg  pneumonia               2

# %%
from PIL import Image
batch_size = 128
validation_split = .3
shuffle_dataset = True
random_seed= 42

# %%
from torch.utils.data.sampler import SubsetRandomSampler
# Creating data indices for training and validation splits:
# from sklearn.model_selection import train_test_split
# tr, val = train_test_split(data.label, stratify=data.label, test_size=0.1)
dataset_size = len(data)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]
#train_indices is equivalent to list(tr.index)
#val_indices is equivalent to list(val.index)

# %%
# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)

# %%
import torchvision.transforms as transforms
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5,0.5), (0.5, 0.5,0.5))])

# %%
from torch.utils.data import Dataset
class chest_Dataset(Dataset):
    def __init__(self, img_data,img_path,transform=None):
        self.img_path = img_path
        self.transform = transform
        self.img_data = img_data
        
    def __len__(self):
        return len(self.img_data)
    
    def __getitem__(self, index):
        img_name = os.path.join(self.img_path,self.img_data.loc[index, 'labels'],
                                self.img_data.loc[index, 'Images'])
        image = Image.open(img_name)
        #image = image.convert('RGB')
        image = image.convert('RGB')
        image = image.resize((300,300))
        label = torch.tensor(self.img_data.loc[index, 'encoded_labels'])
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cpu

# %%
dataset = chest_Dataset(data,BASE_PATH,transform)

# %%
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
                                           sampler=train_sampler)
validation_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                                sampler=valid_sampler)

# %%
def img_display(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    npimg = np.transpose(npimg, (1, 2, 0))
    return npimg

# %%
import matplotlib.pyplot as plt
# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
arthopod_types = {0: 'covid', 1: 'normal', 2: 'pneumonia'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.imshow(img_display(image)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %%
import torch.nn as nn
class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], val_loss: {:.4f}, val_acc: {:.4f}".format(epoch, result['val_loss'], result['val_acc']))

# %%
def evaluate(model, val_loader):
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        for batch in train_loader:
            loss = model.training_step(batch)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
torch.cuda.is_available()
# Out:
# False

# %%
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
def plot_losses(history):
    losses = [x['val_loss'] for x in history]
    plt.plot(losses, '-x')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Loss vs. No. of epochs');

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

# %%
train_loader = DeviceDataLoader(train_loader, device)
val_loader = DeviceDataLoader(validation_loader, device)
#test_loader = DeviceDataLoader(test_loader, device)

# %%
print('images.shape:', images.shape)
# Out:
# images.shape: torch.Size([128, 3, 300, 300])

# %%
input_size = 3*300*300
output_size = 3

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # 3 input image channel, 16 output channels, 3x3 square convolution kernel
        self.conv1 = nn.Conv2d(3,16,kernel_size=3,stride=2,padding=1)
        self.conv2 = nn.Conv2d(16, 32,kernel_size=3,stride=2, padding=1)
        self.conv3 = nn.Conv2d(32, 64,kernel_size=3,stride=2, padding=1)
        self.conv4 = nn.Conv2d(64, 64,kernel_size=3,stride=2, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout2d(0.4)
        self.batchnorm1 = nn.BatchNorm2d(16)
        self.batchnorm2 = nn.BatchNorm2d(32)
        self.batchnorm3 = nn.BatchNorm2d(64)
        self.fc1 = nn.Linear(64*5*5,512 )
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 4)
        
    def forward(self, x):
        x = self.batchnorm1(F.relu(self.conv1(x)))
        x = self.batchnorm2(F.relu(self.conv2(x)))
        x = self.dropout(self.batchnorm2(self.pool(x)))
        x = self.batchnorm3(self.pool(F.relu(self.conv3(x))))
        x = self.dropout(self.conv4(x))
        x = x.view(-1, 64*5*5) # Flatten layer
        x = self.dropout(self.fc1(x))
        x = self.dropout(self.fc2(x))
        x = F.log_softmax(self.fc3(x),dim = 1)
        return x

# %%
model = Net() # On CPU
#model = Net().to(device)  # On GPU
print(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout2d(p=0.4, inplace=False)
#   (batchnorm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=1600, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
def accuracy(out, labels):
    _,pred = torch.max(out, dim=1)
    return torch.sum(pred==labels).item()

# %%
import torch.nn.functional as F
n_epochs = 12
print_every = 10
valid_loss_min = np.Inf
val_loss = []
val_acc = []
train_loss = []
train_acc = []
total_step = len(train_loader)
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    # scheduler.step(epoch)
    correct = 0
    total=0
    print(f'Epoch {epoch}\n')
    for batch_idx, (data_, target_) in enumerate(train_loader):
        #data_, target_ = data_.to(device), target_.to(device)# on GPU
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward + backward + optimize
        outputs = model(data_)
        loss = criterion(outputs, target_)
        loss.backward()
        optimizer.step()
        # print statistics
        running_loss += loss.item()
        _,pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==target_).item()
        total += target_.size(0)
        if (batch_idx) % 20 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain loss: {np.mean(train_loss):.4f}, train acc: {(100 * correct / total):.4f}')
    batch_loss = 0
    total_t=0
    correct_t=0
    with torch.no_grad():
        model.eval()
        for data_t, target_t in (validation_loader):
            #data_t, target_t = data_t.to(device), target_t.to(device)# on GPU
            outputs_t = model(data_t)
            loss_t = criterion(outputs_t, target_t)
            batch_loss += loss_t.item()
            _,pred_t = torch.max(outputs_t, dim=1)
            correct_t += torch.sum(pred_t==target_t).item()
            total_t += target_t.size(0)
        val_acc.append(100 * correct_t / total_t)
        val_loss.append(batch_loss/len(validation_loader))
        network_learned = batch_loss < valid_loss_min
        print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t / total_t):.4f}\n')
        # Saving the best weight 
        if network_learned:
            valid_loss_min = batch_loss
            torch.save(model.state_dict(), 'model_classification_tutorial.pt')
            print('Detected network improvement, saving current model')
    model.train()
# Out:
# Epoch 1
#
# Epoch [1/12], Step [0/38], Loss: 1.4326
# Epoch [1/12], Step [20/38], Loss: 0.8496
#
# train loss: 0.8911, train acc: 65.9531
# validation loss: 0.9937, validation acc: 44.1134
#
# Detected network improvement, saving current model
# Epoch 2
#
# Epoch [2/12], Step [0/38], Loss: 0.6623
# Epoch [2/12], Step [20/38], Loss: 0.5349
#
# train loss: 0.7239, train acc: 81.0210
# validation loss: 0.8697, validation acc: 66.0740
#
# Detected network improvement, saving current model
# Epoch 3
#
# Epoch [3/12], Step [0/38], Loss: 0.4085
# Epoch [3/12], Step [20/38], Loss: 0.4992
#
# train loss: 0.6366, train acc: 84.3763
# validation loss: 0.8243, validation acc: 67.7078
#
# Detected network improvement, saving current model
# Epoch 4
#
# Epoch [4/12], Step [0/38], Loss: 0.4187
# Epoch [4/12], Step [20/38], Loss: 0.2817
#
# train loss: 0.5778, train acc: 87.0111
# validation loss: 0.8047, validation acc: 65.2571
#
# Epoch 5
#
# Epoch [5/12], Step [0/38], Loss: 0.3217
# Epoch [5/12], Step [20/38], Loss: 0.3355
#
# train loss: 0.5375, train acc: 87.8551
# validation loss: 0.7672, validation acc: 76.8381
#
# Detected network improvement, saving current model
# Epoch 6
#
# Epoch [6/12], Step [0/38], Loss: 0.3399
# Epoch [6/12], Step [20/38], Loss: 0.3376
#
# train loss: 0.5066, train acc: 88.6785
# validation loss: 0.7352, validation acc: 80.4421
#
# Detected network improvement, saving current model
# Epoch 7
#
# Epoch [7/12], Step [0/38], Loss: 0.2698
# Epoch [7/12], Step [20/38], Loss: 0.4171
#
# train loss: 0.4808, train acc: 89.2343
# validation loss: 0.7071, validation acc: 83.1812
#
# Detected network improvement, saving current model
# Epoch 8
#
# Epoch [8/12], Step [0/38], Loss: 0.3457
# Epoch [8/12], Step [20/38], Loss: 0.2576
#
# train loss: 0.4599, train acc: 89.6665
# validation loss: 0.6859, validation acc: 83.8059
#
# Detected network improvement, saving current model
# Epoch 9
#
# Epoch [9/12], Step [0/38], Loss: 0.2762
# Epoch [9/12], Step [20/38], Loss: 0.2070
#
# train loss: 0.4417, train acc: 90.4487
# validation loss: 0.6885, validation acc: 70.1586
#
# Epoch 10
#
# Epoch [10/12], Step [0/38], Loss: 0.3870
# Epoch [10/12], Step [20/38], Loss: 0.3189
#
# train loss: 0.4261, train acc: 90.4076
# validation loss: 0.6930, validation acc: 69.0053
#
# Epoch 11
#
# Epoch [11/12], Step [0/38], Loss: 0.2995
# Epoch [11/12], Step [20/38], Loss: 0.2491
#
# train loss: 0.4126, train acc: 90.9634
# validation loss: 0.6803, validation acc: 81.2110
#
# Epoch 12
#
# Epoch [12/12], Step [0/38], Loss: 0.3270
# Epoch [12/12], Step [20/38], Loss: 0.2252
#
# train loss: 0.4004, train acc: 90.9428
# validation loss: 0.6795, validation acc: 71.6963

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(20,10))
plt.title("Train - Validation Loss")
plt.plot( train_loss, label='train')
plt.plot( val_loss, label='validation')
plt.xlabel('num_epochs', fontsize=12)
plt.ylabel('loss', fontsize=12)
plt.legend(loc='best')

# %%
fig = plt.figure(figsize=(20,10))
plt.title("Train - Validation Accuracy")
plt.plot(train_acc, label='train')
plt.plot(val_acc, label='validation')
plt.xlabel('num_epochs', fontsize=12)
plt.ylabel('accuracy', fontsize=12)
plt.legend(loc='best')
